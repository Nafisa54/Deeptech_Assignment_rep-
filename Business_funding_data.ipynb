# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafisa54/Deeptech_Assignment_rep-/blob/main/Business_funding_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installation
# !pip install pandas==2.1.4
# !pip install numpy==1.26.3
# !pip install scikit-learn==1.6.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 72.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 61.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# Import Libraries
import pandas as pd
import numpy as np

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Reading the dataset
df = pd.read_csv("/content/sample_data/Business Funding Data.csv", encoding="latin1")#Change to your file path.
df.head()

# Reading the data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Website Domain             26 non-null     object
#  1   Effective date             6 non-null      object
#  2   Found At                   26 non-null     object
#  3   Financing Type             8 non-null      object
#  4   Financing Type Normalized  8 non-null      object
#  5   Categories                 26 non-null     object
#  6   Investors                  13 non-null     object
#  7   Investors Count            13 non-null     float64
#  8   Amount                     26 non-null     object
#  9   Amount Normalized          26 non-null     int64
#  10  Source Urls                26 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 2.4+ KB

# %% [markdown]
# Checking for Missing Values

# %%
len(df)
# Out:
# 26

# %%
# Determine the percentage of missing value in each column
missing_percentage = df.isnull().sum() / len(df) * 100
missing_percentage
# Out:
# Website Domain                0.000000
# Effective date               76.923077
# Found At                      0.000000
# Financing Type               69.230769
# Financing Type Normalized    69.230769
# Categories                    0.000000
# Investors                    50.000000
# Investors Count              50.000000
# Amount                        0.000000
# Amount Normalized             0.000000
# Source Urls                   0.000000
# dtype: float64

# %%
# Find unique items in the financing type column
df['Financing Type'].unique()
# Out:
# array([nan, 'Series B', 'Series I', 'Seed', 'Series A2', 'Series A'],
#       dtype=object)

# %%
# Find unique items in the financing type column
df['Investors Count'].unique()
# Out:
# array([nan,  9.,  1.,  2.,  3.])

# %%
# Delete the column
df.drop(columns=['Investors Count'], inplace=True)
df
# Out:
#          Website Domain             Effective date                   Found At  \
# 0         trafigura.com                        NaN  2024-03-14T01:00:00+01:00
# 1            zenobe.com                        NaN  2024-05-31T02:00:00+02:00
# 2            zenobe.com                        NaN  2024-07-24T02:00:00+02:00
# 3             canva.com                        NaN  2024-05-01T02:00:00+02:00
# 4          fidelity.com                        NaN  2024-04-11T02:00:00+02:00
# 5       swtchenergy.com  2024-04-18T02:00:00+02:00  2024-04-24T02:00:00+02:00
# 6            carnow.com  2024-04-16T02:00:00+02:00  2024-04-16T02:00:00+02:00
# 7        databricks.com                        NaN  2024-08-07T02:00:00+02:00
# 8         anthropic.com                        NaN  2024-07-08T02:00:00+02:00
# 9                ey.com                        NaN  2024-04-18T02:00:00+02:00
# 10          openpipe.ai                        NaN  2024-03-26T01:00:00+01:00
# ...

# %%
# Delete the column
df.drop(columns=['Effective date'], inplace=True)
df
# Out:
#          Website Domain                   Found At Financing Type  \
# 0         trafigura.com  2024-03-14T01:00:00+01:00           Seed
# 1            zenobe.com  2024-05-31T02:00:00+02:00           Seed
# 2            zenobe.com  2024-07-24T02:00:00+02:00           Seed
# 3             canva.com  2024-05-01T02:00:00+02:00           Seed
# 4          fidelity.com  2024-04-11T02:00:00+02:00           Seed
# 5       swtchenergy.com  2024-04-24T02:00:00+02:00       Series B
# 6            carnow.com  2024-04-16T02:00:00+02:00           Seed
# 7        databricks.com  2024-08-07T02:00:00+02:00       Series I
# 8         anthropic.com  2024-07-08T02:00:00+02:00           Seed
# 9                ey.com  2024-04-18T02:00:00+02:00           Seed
# 10          openpipe.ai  2024-03-26T01:00:00+01:00           Seed
# 11            canva.com  2024-05-09T02:00:00+02:00           Seed
# 12         syntetica.co  2024-07-16T02:00:00+02:00           Seed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Website Domain      26 non-null     object
#  1   Found At            26 non-null     object
#  2   Financing Type      26 non-null     object
#  3   Categories          26 non-null     object
#  4   Investors           13 non-null     object
#  5   Amount              26 non-null     object
#  6   Amount Normalized   26 non-null     int64
#  7   Found At Formatted  26 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.8+ KB

# %%
# Delete the column Source Urls
df.drop(columns=['Source Urls'], inplace=True)
df
# Out:
#          Website Domain             Effective date                   Found At  \
# 0         trafigura.com                        NaN  2024-03-14T01:00:00+01:00
# 1            zenobe.com                        NaN  2024-05-31T02:00:00+02:00
# 2            zenobe.com                        NaN  2024-07-24T02:00:00+02:00
# 3             canva.com                        NaN  2024-05-01T02:00:00+02:00
# 4          fidelity.com                        NaN  2024-04-11T02:00:00+02:00
# 5       swtchenergy.com  2024-04-18T02:00:00+02:00  2024-04-24T02:00:00+02:00
# 6            carnow.com  2024-04-16T02:00:00+02:00  2024-04-16T02:00:00+02:00
# 7        databricks.com                        NaN  2024-08-07T02:00:00+02:00
# 8         anthropic.com                        NaN  2024-07-08T02:00:00+02:00
# 9                ey.com                        NaN  2024-04-18T02:00:00+02:00
# 10          openpipe.ai                        NaN  2024-03-26T01:00:00+01:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Website Domain     26 non-null     object
#  1   Effective date     6 non-null      object
#  2   Found At           26 non-null     object
#  3   Financing Type     8 non-null      object
#  4   Categories         26 non-null     object
#  5   Investors          13 non-null     object
#  6   Investors Count    13 non-null     float64
#  7   Amount             26 non-null     object
#  8   Amount Normalized  26 non-null     int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.0+ KB

# %%
# Filling the missing values of the 'Financing Type' column with their mode.
df['Financing Type'].fillna(df['Financing Type'].mode()[0], inplace=True)
df
# Out:
#          Website Domain                   Found At Financing Type  \
# 0         trafigura.com  2024-03-14 01:00:00+01:00           Seed
# 1            zenobe.com  2024-05-31 02:00:00+02:00           Seed
# 2            zenobe.com  2024-07-24 02:00:00+02:00           Seed
# 3             canva.com  2024-05-01 02:00:00+02:00           Seed
# 4          fidelity.com  2024-04-11 02:00:00+02:00           Seed
# 5       swtchenergy.com  2024-04-24 02:00:00+02:00       Series B
# 6            carnow.com  2024-04-16 02:00:00+02:00           Seed
# 7        databricks.com  2024-08-07 02:00:00+02:00       Series I
# 8         anthropic.com  2024-07-08 02:00:00+02:00           Seed
# 9                ey.com  2024-04-18 02:00:00+02:00           Seed
# 10          openpipe.ai  2024-03-26 01:00:00+01:00           Seed
# 11            canva.com  2024-05-09 02:00:00+02:00           Seed
# 12         syntetica.co  2024-07-16 02:00:00+02:00           Seed
# ...

# %%
# Example: assuming your dataframe is already loaded as df
df["Found At"] = pd.to_datetime(df["Found At"], utc=True)  # convert to datetime

# Helper function for "1st, 2nd, 3rd, 4th..."
def add_ordinal(n):
    return "%d%s" % (n, "tsnrhtdd"[(n//10%10 != 1)*(n%10 < 4)*n%10::4])

# Apply formatting
df["Found At Formatted"] = df["Found At"].apply(
    lambda x: f"{add_ordinal(x.day)} {x.strftime('%B %Y')}"
)

# %%
df
# Out:
#          Website Domain                  Found At Financing Type  \
# 0         trafigura.com 2024-03-14 00:00:00+00:00           Seed
# 1            zenobe.com 2024-05-31 00:00:00+00:00           Seed
# 2            zenobe.com 2024-07-24 00:00:00+00:00           Seed
# 3             canva.com 2024-05-01 00:00:00+00:00           Seed
# 4          fidelity.com 2024-04-11 00:00:00+00:00           Seed
# 5       swtchenergy.com 2024-04-24 00:00:00+00:00       Series B
# 6            carnow.com 2024-04-16 00:00:00+00:00           Seed
# 7        databricks.com 2024-08-07 00:00:00+00:00       Series I
# 8         anthropic.com 2024-07-08 00:00:00+00:00           Seed
# 9                ey.com 2024-04-18 00:00:00+00:00           Seed
# 10          openpipe.ai 2024-03-26 00:00:00+00:00           Seed
# 11            canva.com 2024-05-09 00:00:00+00:00           Seed
# 12         syntetica.co 2024-07-16 00:00:00+00:00           Seed
# ...

# %%
df["Found At"] = pd.to_datetime(df["Found At"]).dt.date

# %%
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
# Delete the column
df.drop(columns=['Found At Formatted'], inplace=True)
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
# Filling the missing values of the 'Categories' column with their mode.
df['Investors'].fillna(df['Investors'].mode(), inplace=True)
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
df[["Amount","Amount Normalized"]].head()
# Out:
#            Amount  Amount Normalized
# 0           $1.9b         1900000000
# 1  $522.7 million          522700000
# 2          £41.7m           53671000
# 3    US$8 million            8000000
# 4   $1.96 million            1960000

# %%
df[["Amount","Amount Normalized"]].describe(include="all")
# Out:
#        Amount  Amount Normalized
# count      26       2.600000e+01
# unique     26                NaN
# top     $1.9b                NaN
# freq        1                NaN
# mean      NaN       2.264687e+08
# std       NaN       5.383239e+08
# min       NaN       1.600000e+06
# 25%       NaN       4.685750e+06
# 50%       NaN       1.160000e+07
# 75%       NaN       4.750000e+07
# max       NaN       2.000000e+09

# %%
for col in ["Amount", "Amount Normalized"]:
  print(f"Unique values in '{col}':")
  print(df[col].unique())
  print("-" * 20)
# Out:
# Unique values in 'Amount':
# ['$1.9b' '$522.7 million' '£41.7m' 'US$8 million' '$1.96 million'
#  '$27.2 Million' '$40 million' '$685 million' '$50mn' 'AU$10.7M'
#  '$6.7 million' '$2 billion' 'Û4.2 million' 'Û425 million' '$10M'
#  'USD 31M' '$5M' '$24.6 million CAD' '$1.6M' '$17.4 million' 'CAD$2.5M'
#  '$10 million' '$5 million CAD' 'US$13.2M' '$2.5M' '$2.5m']
# --------------------
# Unique values in 'Amount Normalized':
# [1900000000  522700000   53671000    8000000    1960000   27200000
#    40000000  685000000   50000000    6865000    6700000 2000000000
#     4581000  464695000   10000000   31000000    5000000   18139000
#     1600000   17400000    1823000    3653000   13200000    2500000]
# --------------------

# %%
# Delete the column
df.drop(columns=['Amount'], inplace=True)
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
df["Categories"].unique()
# Out:
# array(['[]', '["private_equity"]', '["series_b", "venture"]',
#        '["debt_financing"]', '["series_i", "venture"]',
#        '["seed", "venture"]', '["series_a2", "venture"]',
#        '["series_a", "venture"]', '["private_equity", "venture"]'],
#       dtype=object)

# %%
# Filling the missing values of the 'Categories' column with their mode.
df['Categories'].fillna(df['Categories'].mode(), inplace=True)
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
# Determine the percentage of missing value in each column
missing_percentage = df.isnull().sum() / len(df) * 100
missing_percentage
# Out:
# Website Domain        0.000000
# Found At              0.000000
# Financing Type        0.000000
# Categories            0.000000
# Investors            26.923077
# Amount Normalized     0.000000
# dtype: float64

# %%
df["Investors"].isna().sum()
# Out:
# 7

# %%
df["Investors"].isnull().sum()
# Out:
# 7

# %%
df['Investors'].fillna(df['Investors'].mode()[0], inplace=True)
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
df['Categories'].fillna(df['Categories'].mode()[0], inplace=True)
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %%
(df["Categories"] == '[]').sum()
# Out:
# 11

# %%
df["Categories"] = df["Categories"].apply(lambda x: np.nan if x == [] else x)

# %%
df
# Out:
#          Website Domain    Found At Financing Type  \
# 0         trafigura.com  2024-03-14           Seed
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 11            canva.com  2024-05-09           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# ...

# %% [markdown]
# Handling Duplicate

# %%
duplicates = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# Removing Outliers

# %%
# Define a function to calculate Z-scores and remove outliers
def remove_outliers_manual(df, column):
    # Calculate mean and standard deviation
    mean = df[column].mean()
    std_dev = df[column].std()

    # Calculate Z-scores manually
    z_scores = np.abs((df[column] - mean) / std_dev)

    # Filter the rows with Z-scores less than 3
    df_no_outliers = df[z_scores < 3]

    return df_no_outliers

# %%
df = remove_outliers_manual(df, 'Amount Normalized')
df
# Out:
#          Website Domain    Found At Financing Type  \
# 1            zenobe.com  2024-05-31           Seed
# 2            zenobe.com  2024-07-24           Seed
# 3             canva.com  2024-05-01           Seed
# 4          fidelity.com  2024-04-11           Seed
# 5       swtchenergy.com  2024-04-24       Series B
# 6            carnow.com  2024-04-16           Seed
# 7        databricks.com  2024-08-07       Series I
# 8         anthropic.com  2024-07-08           Seed
# 9                ey.com  2024-04-18           Seed
# 10          openpipe.ai  2024-03-26           Seed
# 12         syntetica.co  2024-07-16           Seed
# 13               zf.com  2024-07-15           Seed
# 14        sparelabs.com  2024-06-05           Seed
# 15            e-zinc.ca  2024-06-27      Series A2
# 16  biointelligence.com  2024-04-25           Seed
# 17  claritisoftware.com  2024-04-10           Seed
# 18          heylist.com  2024-06-18           Seed
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
# List of categorical columns to encode
categorical_cols = ['Financing Type', 'Investors', 'Website Domain']

# Apply Label Encoding to each categorical column
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])
# Out:
# /tmp/ipython-input-2017965931.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# /tmp/ipython-input-2017965931.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# /tmp/ipython-input-2017965931.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#     Website Domain    Found At  Financing Type                     Categories  \
# 1               18  2024-05-31               0                             []
# 2               18  2024-07-24               0             ["private_equity"]
# 3                2  2024-05-01               0                             []
# 4                8  2024-04-11               0                             []
# 5               15  2024-04-24               3        ["series_b", "venture"]
# 6                3  2024-04-16               0             ["debt_financing"]
# 7                5  2024-08-07               4        ["series_i", "venture"]
# 8                0  2024-07-08               0                             []
# 9                7  2024-04-18               0                             []
# 10              11  2024-03-26               0            ["seed", "venture"]
# 12              16  2024-07-16               0            ["seed", "venture"]
# ...

# %% [markdown]
# STANDARDAZATION

# %%
df['Amount Normalized'].min()
# Out:
# 1600000

# %%
df['Amount Normalized'].max()
# Out:
# 685000000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()

# %%
# Apply scaling to the 'Mileage' column
df['Amount Normalized'] = scaler.fit_transform(df[['Amount Normalized']])
# Out:
# /tmp/ipython-input-4070478432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount Normalized'] = scaler.fit_transform(df[['Amount Normalized']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 1 to 25
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Website Domain     24 non-null     int64
#  1   Found At           24 non-null     object
#  2   Financing Type     24 non-null     int64
#  3   Categories         24 non-null     object
#  4   Investors          24 non-null     int64
#  5   Amount Normalized  24 non-null     float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.9+ KB
